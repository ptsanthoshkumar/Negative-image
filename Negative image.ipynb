# %%
# !pip install pillow
# Out:
# ...
#      ---------------------------------------- 2.5/2.5 MB 3.8 MB/s eta 0:00:00
# ...

# %%
from PIL import Image
import numpy as np

# %%
from IPython.display import display

# %%
im=Image.open('DP.jpg')

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1068x601>

# %%
ia=np.array(im)

# %%
ia
# Out:
# array([[[ 1,  2,  7],
#         [ 1,  2,  7],
#         [ 2,  3,  8],
#         ...,
#         [ 1,  2,  7],
#         [ 1,  2,  7],
#         [ 1,  2,  7]],
#
#        [[ 1,  2,  7],
#         [ 1,  2,  7],
#         [ 1,  2,  7],
#         ...,
#         [ 1,  2,  7],
#         [ 1,  2,  7],
#         [ 1,  2,  7]],
#
#        [[ 1,  2,  7],
#         [ 1,  2,  7],
#         [ 1,  2,  7],
#         ...,
#         [ 1,  2,  7],
#         [ 1,  2,  7],
#         [ 1,  2,  7]],
#
#        ...,
#
#        [[ 7, 12, 18],
#         [ 6, 11, 17],
#         [ 5, 10, 16],
#         ...,
#         [ 3,  6, 13],
#         [ 2,  5, 12],
#         [ 1,  4, 11]],
#
#        [[ 6, 11, 17],
#         [ 5, 10, 16],
#         [ 4,  9, 15],
#         ...,
#         [ 3,  6, 13],
#         [ 2,  5, 12],
#         [ 1,  4, 11]],
#
#        [[ 5, 10, 16],
#         [ 5, 10, 16],
#         [ 6, 11, 17],
#         ...,
#         [ 2,  5, 12],
#         [ 1,  4, 11],
#         [ 0,  3, 10]]], dtype=uint8)

# %%
mask=np.full(ia.shape,255)

# %%
mask
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
mod=ia-mask
mod=mod*-1
mod=mod.astype(np.uint8)
mod
# Out:
# array([[[254, 253, 248],
#         [254, 253, 248],
#         [253, 252, 247],
#         ...,
#         [254, 253, 248],
#         [254, 253, 248],
#         [254, 253, 248]],
#
#        [[254, 253, 248],
#         [254, 253, 248],
#         [254, 253, 248],
#         ...,
#         [254, 253, 248],
#         [254, 253, 248],
#         [254, 253, 248]],
#
#        [[254, 253, 248],
#         [254, 253, 248],
#         [254, 253, 248],
#         ...,
#         [254, 253, 248],
#         [254, 253, 248],
#         [254, 253, 248]],
#
#        ...,
#
#        [[248, 243, 237],
#         [249, 244, 238],
#         [250, 245, 239],
#         ...,
#         [252, 249, 242],
#         [253, 250, 243],
#         [254, 251, 244]],
#
#        [[249, 244, 238],
#         [250, 245, 239],
#         [251, 246, 240],
#         ...,
#         [252, 249, 242],
#         [253, 250, 243],
#         [254, 251, 244]],
#
#        [[250, 245, 239],
#         [250, 245, 239],
#         [249, 244, 238],
# ...

# %%
display(Image.fromarray(mod))
# Out:
# <PIL.Image.Image image mode=RGB size=1068x601>

# %%
ia.shape
# Out:
# (601, 1068, 3)
